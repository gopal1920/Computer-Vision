# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open("/Users/Admin/OneDrive/Desktop/car.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
img.getbbox()
# Out:
# (0, 0, 275, 183)

# %%
img.format
# Out:
# 'JPEG'

# %%
img.size
# Out:
# (275, 183)

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img.rotate(360)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img1 = img.copy()

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img.paste(img1, (150,150))
img.save("/Users/Admin/OneDrive/Desktop/car2.jpg")

# %%
flip= img.transpose(Image.FLIP_LEFT_RIGHT)
flip
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
croping = img.crop((0,0,150,150))
croping
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
flip2= img1.transpose(Image.FLIP_TOP_BOTTOM)
flip2
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img3 = img1.filter(ImageFilter.BLUR)
img3
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img3.filter(ImageFilter.EDGE_ENHANCE)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img3.filter(ImageFilter.EMBOSS)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img3.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img3.filter(ImageFilter.SMOOTH)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
imagesplit = Image.Image.split(img)

# %%
imagesplit[0].show()

# %%
imagesplit[1].show()

# %%
imagesplit[2].show()

# %%
img_array = np.array(img)
plt.imshow(img_array[:, :, 2], cmap='gray')
