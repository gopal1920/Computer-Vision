# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open("/Users/Admin/OneDrive/Desktop/photo.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1274x1364>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img.mode
# Out:
# 'RGB'

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (1364, 1274, 3)

# %%
plt.imshow(img_array)

# %%
img1 = img_array.copy()
img1[:, :, 0]=0
plt.imshow(img1)

# %%
img2 = img_array.copy()
img2[:, :, 1]=0
plt.imshow(img2)

# %%
img3 = img_array.copy()
img3[:, :, 2]=0
plt.imshow(img3)

# %%
img4 = img_array.copy()
img4[:, :, 0]=0
img4[:, :, 1]=0
img4[:, :, 2]=0
plt.imshow(img4)

# %%
img5 = img_array.copy()
img5[:, :, 0]=255
img5[:, :, 1]=255
img5[:, :, 2]=255
plt.imshow(img5)

# %%
img6 = img_array.copy()
img6[:, :, 0]=0
img6[:, :, 1]=255
img6[:, :, 2]=255
plt.imshow(img6)

# %%
img7 = img_array.copy()
img7[:, :, 0]=255
img7[:, :, 1]=0
img7[:, :, 2]=255
plt.imshow(img7)

# %%
img8 = img_array.copy()
img8[:, :, 0]=255
img8[:, :, 1]=255
img8[:, :, 2]=0
plt.imshow(img8)
